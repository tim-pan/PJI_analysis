# %%
import pandas as pd
te = pd.read_csv('../raw_dataset/ts_Project2.csv')
tr = pd.read_excel('./tr.xlsx')

# %%
feat_final = tr.columns

# %%
te.drop(columns=['OP_time_minute'], inplace=True)

# %%
def draw_hist(df):
    fig = df.hist(figsize=(60, 60),
        xlabelsize=30, 
        ylabelsize=30)

    [x.title.set_size(32) for x in fig.ravel()]

    [x.xaxis.get_major_locator().set_params(integer=True) for x in fig.ravel()]

def draw_boxplot(df):
    fig = df.boxplot(figsize=(30, 60),
                    fontsize=35,
                    rot=45,
                    vert=False)

# %% [markdown]
# ## remove outlier

# %%
draw_boxplot(te)
te.CBC_Platelet.describe()
idma = te.CBC_Platelet.idxmax()
te.drop(idma, inplace=True)
#the reason why I didnot remove CBC_Platelet=600 is because there is still 
# probably to show this value in clinical test

# %%
draw_boxplot(te)

# %%
draw_hist(te)

# %%
te.shape
# Out:
# (489, 66)

# %%
te.dtypes.value_counts()
# Out:
# int64      44
# float64    20
# object      2
# dtype: int64

# %% [markdown]
# ## data imputation and transform

# %%
pd.set_option('display.max_rows', None)
te.isnull().sum()
# Out:
# AGE                                          0
# SEX                                          0
# LOS                                          0
# Joint                                        0
# Drain                                        0
# Cemented                                     0
# Commercial_ALBC                              0
# Non_commercial_ALBC                          0
# cci_index                                    0
# elx_index                                    0
# Blood_trans                                  0
# OP_time_hour                               185
# ASA                                        186
# CBC_WBC                                    343
# CBC_RBC                                    342
# CBC_HG                                     263
# CBC_HT                                     260
# CBC_MCV                                    345
# CBC_MCH                                    346
# CBC_MCHC                                   346
# CBC_RDW                                    347
# CBC_Platelet                               343
# CBC_RDWCV                                  460
# BUN                                        266
# Crea                                       282
# GOT                                        274
# GPT                                        320
# ALB                                        346
# Na                                         350
# K                                          351
# UA                                         364
# Diagnosis                                    0
# Congestive Heart Failure                     0
# Cardiac Arrhythmia                           0
# Valvular Disease                             0
# Heart disease                                0
# Pulmonary Circulation Disorders              0
# Peripheral Vascular Disorders                0
# Hypertension Uncomplicated                   0
# Paralysis                                    0
# Other Neurological Disorders                 0
# Chronic Pulmonary Disease                    0
# Lung disease                                 0
# Diabetes                                     0
# Hypothyroidism                               0
# Renal Failure                                0
# Liver Disease                                0
# Peptic Ulcer Disease excluding bleeding      0
# AIDS/HIV                                     0
# Lymphoma                                     0
# Metastatic Cancer                            0
# Solid Tumor without Metastasis               0
# Cancer history                               0
# Rheumatoid Arthritis/collagen                0
# Coagulopathy                                 0
# Obesity                                      0
# Weight Loss                                  0
# Fluid and Electrolyte Disorders              0
# Blood Loss Anemia                            0
# Deficiency Anemia                            0
# Anemia                                       0
# Alcohol Abuse                                0
# Drug Abuse                                   0
# Psychoses                                    0
# Depression                                   0
# Psyciatric disorder                          0
# dtype: int64

# %% [markdown]
# #### nomial (object)

# %%
te.columns
# Out:
# Index(['AGE', 'SEX', 'LOS', 'Joint', 'Drain', 'Cemented', 'Commercial_ALBC',
#        'Non_commercial_ALBC', 'cci_index', 'elx_index', 'Blood_trans',
#        'OP_time_hour', 'ASA', 'CBC_WBC', 'CBC_RBC', 'CBC_HG', 'CBC_HT',
#        'CBC_MCV', 'CBC_MCH', 'CBC_MCHC', 'CBC_RDW', 'CBC_Platelet',
#        'CBC_RDWCV', 'BUN', 'Crea', 'GOT', 'GPT', 'ALB', 'Na', 'K', 'UA',
#        'Diagnosis', 'Congestive Heart Failure', 'Cardiac Arrhythmia',
#        'Valvular Disease', 'Heart disease', 'Pulmonary Circulation Disorders',
#        'Peripheral Vascular Disorders', 'Hypertension Uncomplicated',
#        'Paralysis', 'Other Neurological Disorders',
#        'Chronic Pulmonary Disease', 'Lung disease', 'Diabetes',
#        'Hypothyroidism', 'Renal Failure', 'Liver Disease',
#        'Peptic Ulcer Disease excluding bleeding', 'AIDS/HIV', 'Lymphoma',
#        'Metastatic Cancer', 'Solid Tumor without Metastasis', 'Cancer history',
#        'Rheumatoid Arthritis/collagen', 'Coagulopathy', 'Obesity',
#        'Weight Loss', 'Fluid and Electrolyte Disorders', 'Blood Loss Anemia',
#        'Deficiency Anemia', 'Anemia', 'Alcohol Abuse', 'Drug Abuse',
#        'Psychoses', 'Depression', 'Psyciatric disorder'],
#       dtype='object')

# %%
te = pd.get_dummies(te)
te.dtypes
te.select_dtypes('uint8').columns
# Out:
# Index(['SEX_F', 'SEX_M', 'Joint_THA', 'Joint_TKA'], dtype='object')

# %% [markdown]
# #### ordinal on elx_index and cci_index(discreterize)
# other ordinal considered as continous after minmax

# %%
te.columns
# Out:
# Index(['AGE', 'LOS', 'Drain', 'Cemented', 'Commercial_ALBC',
#        'Non_commercial_ALBC', 'cci_index', 'elx_index', 'Blood_trans',
#        'OP_time_hour', 'ASA', 'CBC_WBC', 'CBC_RBC', 'CBC_HG', 'CBC_HT',
#        'CBC_MCV', 'CBC_MCH', 'CBC_MCHC', 'CBC_RDW', 'CBC_Platelet',
#        'CBC_RDWCV', 'BUN', 'Crea', 'GOT', 'GPT', 'ALB', 'Na', 'K', 'UA',
#        'Diagnosis', 'Congestive Heart Failure', 'Cardiac Arrhythmia',
#        'Valvular Disease', 'Heart disease', 'Pulmonary Circulation Disorders',
#        'Peripheral Vascular Disorders', 'Hypertension Uncomplicated',
#        'Paralysis', 'Other Neurological Disorders',
#        'Chronic Pulmonary Disease', 'Lung disease', 'Diabetes',
#        'Hypothyroidism', 'Renal Failure', 'Liver Disease',
#        'Peptic Ulcer Disease excluding bleeding', 'AIDS/HIV', 'Lymphoma',
#        'Metastatic Cancer', 'Solid Tumor without Metastasis', 'Cancer history',
#        'Rheumatoid Arthritis/collagen', 'Coagulopathy', 'Obesity',
#        'Weight Loss', 'Fluid and Electrolyte Disorders', 'Blood Loss Anemia',
#        'Deficiency Anemia', 'Anemia', 'Alcohol Abuse', 'Drug Abuse',
#        'Psychoses', 'Depression', 'Psyciatric disorder', 'SEX_F', 'SEX_M',
#        'Joint_THA', 'Joint_TKA'],
#       dtype='object')

# %%
#onehot for column_need_onehot
column_need_onehot = ['Diagnosis', 'Heart disease', 'Lung disease', 'Cancer history', 'Anemia', 'Psyciatric disorder']
confuse = ['cci_index', 'elx_index']
te[column_need_onehot] = te[column_need_onehot].astype('object')
te = pd.get_dummies(te)
te.columns
# Out:
# Index(['AGE', 'LOS', 'Drain', 'Cemented', 'Commercial_ALBC',
#        'Non_commercial_ALBC', 'cci_index', 'elx_index', 'Blood_trans',
#        'OP_time_hour', 'ASA', 'CBC_WBC', 'CBC_RBC', 'CBC_HG', 'CBC_HT',
#        'CBC_MCV', 'CBC_MCH', 'CBC_MCHC', 'CBC_RDW', 'CBC_Platelet',
#        'CBC_RDWCV', 'BUN', 'Crea', 'GOT', 'GPT', 'ALB', 'Na', 'K', 'UA',
#        'Congestive Heart Failure', 'Cardiac Arrhythmia', 'Valvular Disease',
#        'Pulmonary Circulation Disorders', 'Peripheral Vascular Disorders',
#        'Hypertension Uncomplicated', 'Paralysis',
#        'Other Neurological Disorders', 'Chronic Pulmonary Disease', 'Diabetes',
#        'Hypothyroidism', 'Renal Failure', 'Liver Disease',
#        'Peptic Ulcer Disease excluding bleeding', 'AIDS/HIV', 'Lymphoma',
#        'Metastatic Cancer', 'Solid Tumor without Metastasis',
#        'Rheumatoid Arthritis/collagen', 'Coagulopathy', 'Obesity',
#        'Weight Loss', 'Fluid and Electrolyte Disorders', 'Blood Loss Anemia',
#        'Deficiency Anemia', 'Alcohol Abuse', 'Drug Abuse', 'Psychoses',
#        'Depression', 'SEX_F', 'SEX_M', 'Joint_THA', 'Joint_TKA', 'Diagnosis_0',
#        'Diagnosis_1', 'Diagnosis_2', 'Diagnosis_3', 'Diagnosis_4',
#        'Diagnosis_5', 'Heart disease_0', 'Heart disease_1', 'Heart disease_2',
#        'Heart disease_3', 'Lung disease_0', 'Lung disease_1', 'Lung disease_2',
#        'Cancer history_0', 'Cancer history_1', 'Cancer history_2', 'Anemia_0',
#        'Anemia_1', 'Psyciatric disorder_0', 'Psyciatric disorder_1'],
#       dtype='object')

# %%
#discreterize for elx_index, since there are too many class in this attr
els_bin = [-1, 2, 4, 6, 8, 10, 13]
new_elx = pd.get_dummies(pd.cut(te['elx_index'], bins=els_bin))#5 class
new_elx.columns = ['elx1', 'elx2', 'elx3', 'elx4', 'elx5', 'elx6']
te = pd.concat((te, new_elx), axis=1)
te.drop(columns='elx_index', inplace=True)

# %%
#discreterize for cci_index, since there are too many class in this attr
new_cci = pd.get_dummies(pd.cut(te['cci_index'], bins=[-1, 0, 4, 7, 12, 15]))#5 class
new_cci.columns = ['cci1', 'cci2', 'cci3', 'cci4', 'cci5']
te = pd.concat((te, new_cci), axis=1)
te.drop(columns='cci_index', inplace=True)

# %%
te.select_dtypes('uint8').columns
# Out:
# Index(['SEX_F', 'SEX_M', 'Joint_THA', 'Joint_TKA', 'Diagnosis_0',
#        'Diagnosis_1', 'Diagnosis_2', 'Diagnosis_3', 'Diagnosis_4',
#        'Diagnosis_5', 'Heart disease_0', 'Heart disease_1', 'Heart disease_2',
#        'Heart disease_3', 'Lung disease_0', 'Lung disease_1', 'Lung disease_2',
#        'Cancer history_0', 'Cancer history_1', 'Cancer history_2', 'Anemia_0',
#        'Anemia_1', 'Psyciatric disorder_0', 'Psyciatric disorder_1', 'elx1',
#        'elx2', 'elx3', 'elx4', 'elx5', 'elx6', 'cci1', 'cci2', 'cci3', 'cci4',
#        'cci5'],
#       dtype='object')

# %%
te.dtypes.value_counts()
# Out:
# int64      36
# uint8      35
# float64    20
# dtype: int64

# %%
col = te.select_dtypes('uint8').columns
print(col)
te[col] = te[col].astype('int64')
# col = te.select_dtypes('int').columns
# te[col] = te[col].astype('object')
# Out:
# Index(['SEX_F', 'SEX_M', 'Joint_THA', 'Joint_TKA', 'Diagnosis_0',
#        'Diagnosis_1', 'Diagnosis_2', 'Diagnosis_3', 'Diagnosis_4',
#        'Diagnosis_5', 'Heart disease_0', 'Heart disease_1', 'Heart disease_2',
#        'Heart disease_3', 'Lung disease_0', 'Lung disease_1', 'Lung disease_2',
#        'Cancer history_0', 'Cancer history_1', 'Cancer history_2', 'Anemia_0',
#        'Anemia_1', 'Psyciatric disorder_0', 'Psyciatric disorder_1', 'elx1',
#        'elx2', 'elx3', 'elx4', 'elx5', 'elx6', 'cci1', 'cci2', 'cci3', 'cci4',
#        'cci5'],
#       dtype='object')

# %%
te.dtypes.value_counts()
# Out:
# int64      71
# float64    20
# dtype: int64

# %%
int_col = te.select_dtypes('int64').columns
print(int_col)
float_col = te.select_dtypes('float').columns
print(float_col)
# Out:
# Index(['AGE', 'LOS', 'Drain', 'Cemented', 'Commercial_ALBC',
#        'Non_commercial_ALBC', 'Blood_trans', 'Congestive Heart Failure',
#        'Cardiac Arrhythmia', 'Valvular Disease',
#        'Pulmonary Circulation Disorders', 'Peripheral Vascular Disorders',
#        'Hypertension Uncomplicated', 'Paralysis',
#        'Other Neurological Disorders', 'Chronic Pulmonary Disease', 'Diabetes',
#        'Hypothyroidism', 'Renal Failure', 'Liver Disease',
#        'Peptic Ulcer Disease excluding bleeding', 'AIDS/HIV', 'Lymphoma',
#        'Metastatic Cancer', 'Solid Tumor without Metastasis',
#        'Rheumatoid Arthritis/collagen', 'Coagulopathy', 'Obesity',
#        'Weight Loss', 'Fluid and Electrolyte Disorders', 'Blood Loss Anemia',
#        'Deficiency Anemia', 'Alcohol Abuse', 'Drug Abuse', 'Psychoses',
#        'Depression', 'SEX_F', 'SEX_M', 'Joint_THA', 'Joint_TKA', 'Diagnosis_0',
#        'Diagnosis_1', 'Diagnosis_2', 'Diagnosis_3', 'Diagnosis_4',
#        'Diagnosis_5', 'Heart disease_0', 'Heart disease_1', 'Heart disease_2',
#        'Heart disease_3', 'Lung disease_0', 'Lung disease_1', 'Lung disease_2',
#        'Cancer history_0', 'Cancer history_1', 'Cancer history_2', 'Anemia_0',
#        'Anemia_1', 'Psyciatric disorder_0', 'Psyciatric disorder_1', 'elx1',
#        'elx2', 'elx3', 'elx4', 'elx5', 'elx6', 'cci1', 'cci2', 'cci3', 'cci4',
#        'cci5'],
#       dtype='object')
# Index(['OP_time_hour', 'ASA', 'CBC_WBC', 'CBC_RBC', 'CBC_HG', 'CBC_HT',
#        'CBC_MCV', 'CBC_MCH', 'CBC_MCHC', 'CBC_RDW', 'CBC_Platelet',
#        'CBC_RDWCV', 'BUN', 'Crea', 'GOT', 'GPT', 'ALB', 'Na', 'K', 'UA'],
#       dtype='object')

# %% [markdown]
# #### numeric attr

# %%
# fortunately, misasing values are all in the float columns: KNN imputation
float_missing_col = ['OP_time_minute', 'OP_time_hour', 'ASA', 'CBC_WBC', 'CBC_RBC', 
                     'CBC_HG', 'CBC_HT', 'CBC_MCV', 'CBC_MCH', 'CBC_MCHC', 'CBC_RDW', 
                     'CBC_Platelet', 'CBC_RDWCV','BUN', 'Crea', 'GOT', 'GPT', 'ALB',
                     'Na', 'K', 'UA']
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.preprocessing import minmax_scale

new_te = minmax_scale(te)

#deal with commensurate in float attr(including ordinal attr)
col = te.columns
te = pd.DataFrame(new_te, columns=col)

# %%
te.describe().transpose()
#there are some columns all zero
# Out:
#                                          count      mean       std  min  \
# AGE                                      489.0  0.653024  0.171622  0.0
# LOS                                      489.0  0.105437  0.095646  0.0
# Drain                                    489.0  0.752556  0.431969  0.0
# Cemented                                 489.0  0.697342  0.459879  0.0
# Commercial_ALBC                          489.0  0.085890  0.280488  0.0
# Non_commercial_ALBC                      489.0  0.613497  0.487447  0.0
# Blood_trans                              489.0  0.122699  0.328428  0.0
# OP_time_hour                             304.0  0.309627  0.162552  0.0
# ASA                                      303.0  0.691419  0.278345  0.0
# CBC_WBC                                  146.0  0.408265  0.211429  0.0
# CBC_RBC                                  147.0  0.474766  0.128769  0.0
# CBC_HG                                   226.0  0.578120  0.207519  0.0
# CBC_HT                                   229.0  0.573316  0.186662  0.0
# CBC_MCV                                  144.0  0.644160  0.166209  0.0
# CBC_MCH                                  143.0  0.690672  0.171083  0.0
# CBC_MCHC                                 143.0  0.643586  0.186435  0.0
# CBC_RDW                                  142.0  0.206102  0.304956  0.0
# CBC_Platelet                             146.0  0.491830  0.172052  0.0
# CBC_RDWCV                                 29.0  0.321003  0.234874  0.0
# BUN                                      223.0  0.236697  0.121052  0.0
# Crea                                     207.0  0.266281  0.142364  0.0
# GOT                                      215.0  0.194498  0.161448  0.0
# GPT                                      169.0  0.184962  0.146811  0.0
# ALB                                      143.0  0.600584  0.245602  0.0
# Na                                       139.0  0.661493  0.140299  0.0
# K                                        138.0  0.558095  0.245614  0.0
# UA                                       125.0  0.393927  0.182634  0.0
# Congestive Heart Failure                 489.0  0.030675  0.172612  0.0
# Cardiac Arrhythmia                       489.0  0.040900  0.198261  0.0
# Valvular Disease                         489.0  0.032720  0.178085  0.0
# Pulmonary Circulation Disorders          489.0  0.002045  0.045222  0.0
# Peripheral Vascular Disorders            489.0  0.010225  0.100703  0.0
# Hypertension Uncomplicated               489.0  0.316973  0.465773  0.0
# Paralysis                                489.0  0.004090  0.063887  0.0
# Other Neurological Disorders             489.0  0.016360  0.126985  0.0
# Chronic Pulmonary Disease                489.0  0.059305  0.236436  0.0
# Diabetes                                 489.0  0.106339  0.308587  0.0
# Hypothyroidism                           489.0  0.012270  0.110201  0.0
# Renal Failure                            489.0  0.032720  0.178085  0.0
# Liver Disease                            489.0  0.063395  0.243921  0.0
# Peptic Ulcer Disease excluding bleeding  489.0  0.049080  0.216256  0.0
# AIDS/HIV                                 489.0  0.000000  0.000000  0.0
# Lymphoma                                 489.0  0.000000  0.000000  0.0
# Metastatic Cancer                        489.0  0.002045  0.045222  0.0
# Solid Tumor without Metastasis           489.0  0.038855  0.193447  0.0
# Rheumatoid Arthritis/collagen            489.0  0.049080  0.216256  0.0
# Coagulopathy                             489.0  0.006135  0.078165  0.0
# Obesity                                  489.0  0.010225  0.100703  0.0
# Weight Loss                              489.0  0.000000  0.000000  0.0
# Fluid and Electrolyte Disorders          489.0  0.016360  0.126985  0.0
# Blood Loss Anemia                        489.0  0.004090  0.063887  0.0
# Lung disease_2                           0.000000  0.000000  0.000000  1.0
# Cancer history_0                         1.000000  1.000000  1.000000  1.0
# Cancer history_1                         0.000000  0.000000  0.000000  1.0
# Cancer history_2                         0.000000  0.000000  0.000000  1.0
# Anemia_0                                 1.000000  1.000000  1.000000  1.0
# Anemia_1                                 0.000000  0.000000  0.000000  1.0
# Psyciatric disorder_0                    1.000000  1.000000  1.000000  1.0
# Psyciatric disorder_1                    0.000000  0.000000  0.000000  1.0
# elx1                                     1.000000  1.000000  1.000000  1.0
# elx2                                     0.000000  0.000000  0.000000  1.0
# elx3                                     0.000000  0.000000  0.000000  1.0
# elx4                                     0.000000  0.000000  0.000000  1.0
# elx5                                     0.000000  0.000000  0.000000  0.0
# elx6                                     0.000000  0.000000  0.000000  0.0
# cci1                                     0.000000  1.000000  1.000000  1.0
# cci2                                     0.000000  0.000000  1.000000  1.0
# cci3                                     0.000000  0.000000  0.000000  1.0
# cci4                                     0.000000  0.000000  0.000000  1.0
# cci5                                     0.000000  0.000000  0.000000  0.0

# %%
zero_column = ['AIDS/HIV', 'Lymphoma', 'Metastatic Cancer', 'Weight Loss', 
   'Blood Loss Anemia', 'elx4', 'elx5', 'elx6', 'cci4', 'cci5']

# %% [markdown]
# #### continous attr

# %%
imputer = KNNImputer(n_neighbors=15)
new_te = imputer.fit_transform(te)

# %%
int_col
# Out:
# Index(['AGE', 'LOS', 'Drain', 'Cemented', 'Commercial_ALBC',
#        'Non_commercial_ALBC', 'Blood_trans', 'Congestive Heart Failure',
#        'Cardiac Arrhythmia', 'Valvular Disease',
#        'Pulmonary Circulation Disorders', 'Peripheral Vascular Disorders',
#        'Hypertension Uncomplicated', 'Paralysis',
#        'Other Neurological Disorders', 'Chronic Pulmonary Disease', 'Diabetes',
#        'Hypothyroidism', 'Renal Failure', 'Liver Disease',
#        'Peptic Ulcer Disease excluding bleeding', 'AIDS/HIV', 'Lymphoma',
#        'Metastatic Cancer', 'Solid Tumor without Metastasis',
#        'Rheumatoid Arthritis/collagen', 'Coagulopathy', 'Obesity',
#        'Weight Loss', 'Fluid and Electrolyte Disorders', 'Blood Loss Anemia',
#        'Deficiency Anemia', 'Alcohol Abuse', 'Drug Abuse', 'Psychoses',
#        'Depression', 'SEX_F', 'SEX_M', 'Joint_THA', 'Joint_TKA', 'Diagnosis_0',
#        'Diagnosis_1', 'Diagnosis_2', 'Diagnosis_3', 'Diagnosis_4',
#        'Diagnosis_5', 'Heart disease_0', 'Heart disease_1', 'Heart disease_2',
#        'Heart disease_3', 'Lung disease_0', 'Lung disease_1', 'Lung disease_2',
#        'Cancer history_0', 'Cancer history_1', 'Cancer history_2', 'Anemia_0',
#        'Anemia_1', 'Psyciatric disorder_0', 'Psyciatric disorder_1', 'elx1',
#        'elx2', 'elx3', 'elx4', 'elx5', 'elx6', 'cci1', 'cci2', 'cci3', 'cci4',
#        'cci5'],
#       dtype='object')

# %%
te[te.columns] = new_te
draw_hist(te)
# te[int_col] = te[int_col.astype('int64')

# %%
te.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## feature selection

# %%
feat_final = feat_final[:-1]

# %%
te = te[feat_final]

# %%
te.transpose()
# Out:
#                                               0         1         2    \
# Fluid and Electrolyte Disorders          0.000000  0.000000  0.000000
# cci3                                     0.000000  0.000000  0.000000
# Hypothyroidism                           0.000000  0.000
#
#                                               9    ...       479       480  \
# Fluid and Electrolyte Disorders          0.000000  ...  0.000000  0.000000
# cci3                                     0.000000  ...  0.000000  0.000000
# Hypothyroidism                           0.000000  ...  0.000000  0.000000
# elx3                                     0.000000  ...  0.000000  0.000000
# Valvular Disease                         0.000000  ...  0.000000  0.000000
# Diagnosis_5                              0.000000  ...  0.000000  0.000000
# Anemia_0                                 1.000000  ...  1.000000  1.000000
# Other Neurological Disorders             0.000000  ...  0.000000  0.000000
# Obesity                                  0.000000  ...  0.000000  0.000000
# Congestive Heart Failure                 0.000000  ...  0.000000  0.000000
# Psyciatric disorder_0                    1.000000  ...  1.000000  1.000000
# Renal Failure                            0.000000  ...  0.000000  0.000000
# Diagnosis_2                              0.000000  ...  0.000000  0.000000
# Diagnosis_3                              0.000000  ...  0.000000  0.000000
# Lung disease_0                           1.000000  ...  1.000000  1.000000
# Solid Tumor without Metastasis           0.000000  ...  0.000000  0.000000
# Peptic Ulcer Disease excluding bleeding  1.000000  ...  0.000000  0.000000
# Rheumatoid Arthritis/collagen            0.000000  ...  0.000000  0.000000
# Liver Disease                            1.000000  ...  0.000000  0.000000
# Heart disease_0                          1.000000  ...  1.000000  1.000000
# elx1                                     0.000000  ...  1.000000  1.000000
# Diabetes                                 0.000000  ...  0.000000  0.000000
# Commercial_ALBC                          0.000000  ...  0.000000  0.000000
# Blood_trans                              1.000000  ...  1.000000  0.000000
# Drain                                    1.000000  ...  1.000000  1.000000
# Diagnosis_0                              0.000000  ...  1.000000  1.000000
# Non_commercial_ALBC                      0.000000  ...  1.000000  1.000000
# Hypertension Uncomplicated               1.000000  ...  0.000000  0.000000
# cci1                                     0.000000  ...  1.000000  1.000000
# SEX_F                                    0.000000  ...  1.000000  1.000000
# CBC_MCV                                  0.708788  ...  0.870455  0.685152
# BUN                                      0.191279  ...  0.360895  0.226749
# UA                                       0.411156  ...  0.387891  0.392789
# GPT                                      0.194253  ...  0.209770  0.198851
# GOT                                      0.183740  ...  0.234959  0.265854
# CBC_HG                                   0.680460  ...  0.517241  0.547126
# OP_time_hour                             0.350211  ...  0.362869  0.287764
# CBC_RBC                                  0.489655  ...  0.253695  0.434647
# CBC_MCHC                                 0.748634  ...  0.737705  0.671038
# AGE                                      0.552632  ...  0.842105  0.789474
# ASA                                      0.633333  ...  1.000000  0.533333
# CBC_Platelet                             0.448304  ...  0.612903  0.473284
# Na                                       0.627750  ...  0.812500  0.662750
# CBC_WBC                                  0.451685  ...  0.662921  0.387266
# CBC_RDWCV                                0.290909  ...  0.287273  0.316364
# ALB                                      0.606621  ...  0.756849  0.633105
# K                                        0.462344  ...  0.520364  0.581797
# Crea                                     0.247251  ...  0.213985  0.268024
# CBC_RDW                                  0.149577  ...  0.048223  0.248900
# LOS                                      0.411765  ...  0.117647  0.147059
#
#                                               481       482       483  \
# Fluid and Electrolyte Disorders          0.000000  0.000000  0.000000
# cci3                                     0.000000  0.000000  0.000000
# Hypothyroidism                           0.000000  0.000000  0.000000
# elx3                                     0.000000  0.000000  0.000000
# Valvular Disease                         0.000000  0.000000  0.000000
# Diagnosis_5                              0.000000  0.000000  0.000000
# Anemia_0                                 1.000000  1.000000  1.000000
# Other Neurological Disorders             0.000000  0.000000  0.000000
# Obesity                                  0.000000  0.000000  0.000000
# Congestive Heart Failure                 0.000000  0.000000  0.000000
# Psyciatric disorder_0                    1.000000  1.000000  1.000000
# Renal Failure                            0.000000  0.000000  0.000000
# Diagnosis_2                              0.000000  0.000000  0.000000
# Diagnosis_3                              0.000000  0.000000  0.000000
# Lung disease_0                           1.000000  1.000000
# OP_time_hour                             0.329114  0.303797  0.194093
# CBC_RBC                                  0.481281  0.464368  0.472085
# CBC_MCHC                                 0.600000  0.570492  0.603279
# AGE                                      0.855263  0.802632  0.815789
# ASA                                      1.000000  1.000000  1.000000
# CBC_Platelet                             0.422167  0.484086  0.459388
# Na                                       0.480000  0.619833  0.704583
# CBC_WBC                                  0.375281  0.390262  0.381273
# CBC_RDWCV                                0.316364  0.315152  0.315152
# ALB                                      0.345890  0.328767  0.505479
# K                                        0.273038  0.515813  0.544255
# Crea                                     0.040733  0.173116  0.237339
# CBC_RDW                                  0.063959  0.303553  0.211675
# LOS                                      0.058824  0.117647  0.088235
#
#                                               487       488
# Fluid and Electrolyte Disorders          0.000000  0.000000
# cci3                                     0.000000  0.000000
# Hypothyroidism                           0.000000  0.000000
# elx3                                     0.000000  0.000000
# Valvular Disease                         0.000000  0.000000
# Diagnosis_5                              0.000000  0.000000
# Anemia_0                                 1.000000  1.000000
# Other Neurological Disorders             0.000000  0.000000
# Obesity                                  0.000000  0.000000
# Congestive Heart Failure                 0.000000  0.000000
# Psyciatric disorder_0                    1.000000  1.000000
# Renal Failure                            0.000000  0.000000
# Diagnosis_2                              0.000000  0.000000
# Diagnosis_3                              0.000000  1.000000
# Lung disease_0                           1.000000  1.000000
# Solid Tumor without Metastasis           0.000000  0.000000
# Peptic Ulcer Disease excluding bleeding  0.000000  0.000000
# Rheumatoid Arthritis/collagen            0.000000  0.000000
# Liver Disease                            0.000000  0.000000
# Heart disease_0                          1.000000  1.000000
# elx1                                     1.000000  1.000000
# Diabetes                                 0.000000  0.000000
# Commercial_ALBC                          0.000000  0.000000
# Blood_trans                              0.000000  0.000000
# Drain                                    1.000000  1.000000
# Diagnosis_0                              0.000000  0.000000
# Non_commercial_ALBC                      0.000000  0.000000
# Hypertension Uncomplicated               0.000000  0.000000
# cci1                                     1.000000  1.000000
# SEX_F                                    1.000000  0.000000
# CBC_MCV                                  0.752121  0.661364
# BUN                                      0.215698  0.121230
# UA                                       0.332653  0.489796
# GPT                                      0.051724  0.103448
# GOT                                      0.036585  0.121951
# CBC_HG                                   0.494253  0.873563
# OP_time_hour                             0.409283  0.353305
# CBC_RBC                                  0.451888  0.593596
# CBC_MCHC                                 0.722404  0.770492
# AGE                                      0.684211  0.078947
# ASA                                      0.500000  0.400000
# CBC_Platelet                             0.576510  0.647643
# Na                                       0.605000  0.615500
# CBC_WBC                                  0.559551  0.235955
# CBC_RDWCV                                0.306667  0.238788
# ALB                                      0.479452  0.928082
# K                                        0.273038  0.606598
# Crea                                     0.046843  0.391039
# CBC_RDW                                  0.106430  0.038071
# LOS                                      0.088235  0.117647
#
# [50 rows x 489 columns]

# %%
list(set(feat_final)&set(zero_column))
# there is no intersection between zero columns and feat final columns
# Out:
# []

# %%
# onehot_col = te.iloc[0:30, 0:30].columns
# onehot_col = onehot_col.insert(31, 'outcome')
# te[onehot_col] = te[onehot_col].astype("int")

# %%
draw_hist(te)

# %% [markdown]
# ## save final set

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('./test_final.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
te.to_excel(writer, sheet_name='Sheet1', index=False)

# Close the Pandas Excel writer and output the Excel file.
writer.save()
