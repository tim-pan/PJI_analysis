# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def draw_fig(path_csv):
    df = pd.read_csv(path_csv, index_col=False)
    df = df.iloc[:, 1:]
    cols = df.columns

    metric_cols = cols[-5:]
    para_set_cols = [item for item in cols if item not in set(metric_cols)]

    X = df[para_set_cols].values.tolist()
    Y = df[metric_cols].T.to_numpy()
    
    plt.figure(figsize=(5, 5))
    for _, y in zip(X, Y): 
        plt.plot(y, marker='o')
        
    plt.xticks(range(len(y)), [str(item) for item in X], rotation=90)
    plt.xlabel('parameter setup')
    plt.title(f'x cordinate means values of {para_set_cols}')
    plt.legend(['precision', 'recall', 'ROC', 'f1', 'acc'])
    
    plt.show()
    
    return df

# %%
draw_fig('./c45_result_smote.csv')
# Out:
#   criterion  precision    recall       ROC        f1       acc
# 0      gini   0.963649  0.982206  0.972575  0.972839  0.972576
# 1   entropy   0.967893  0.980987  0.974221  0.974396  0.974221

# %%
draw_fig('./c45_result_smote_pca.csv')
# Out:
#   criterion  precision    recall       ROC        f1       acc
# 0      gini   0.963295  0.981962  0.972271  0.972539  0.972271
# 1   entropy   0.966935  0.980134  0.973307  0.973490  0.973307

# %%
draw_fig('./c45_result_rs.csv')
# Out:
#   criterion  precision    recall       ROC        f1       acc
# 0      gini   0.642857  0.638298  0.641844  0.640569  0.641844
# 1   entropy   0.678571  0.673759  0.677305  0.676157  0.677305

# %%
draw_fig('./c45_result_rs_pca.csv')
# Out:
#   criterion  precision    recall       ROC        f1       acc
# 0      gini   0.625954  0.581560  0.617021  0.602941  0.617021
# 1   entropy   0.622222  0.595745  0.617021  0.608696  0.617021
